# %% [markdown]
# <a href="https://colab.research.google.com/github/Hocuspocus12/Hello-world-/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf


num_points = 1200
data=[]
m=0.2
c=0.5
for i in range(num_points):
  x = np.random.normal(0.0,0.8)
  noise = np.random.normal(0.0,0.4)
  y = m*x + c + noise
  data.append([x,y])
x_data=[d[0] for d in data]
y_data=[d[1] for d in data]
plt.plot(x_data,y_data,'ro')
plt.title('input data')
plt.show()

W=tf.Variable(tf.random_uniform([1],-1.0,1.0))
b=tf.Variable(tf.zeros([1]))
y=W*x_data+b
loss=tf.reduce_mean(tf.square(y - y_data))
optimizer=tf.train.GradientDescentOptimizer(0.5)
train =optimizer.minimize(loss)
init=tf.initialize_all_variables()
sess = tf.Session()
sess.run(init)
num_iterations=10
for step in range(num_iterations):
  sess.run(train)
  print('n iteration',step+1)
  print('w =:',sess.run(W)[0])
  print('b =:',sess.run(b)[0])
  print('loss=:',sess.run(loss))

  plt.plot(x_data,y_data,'ro')
  plt.plot(x_data,sess.run(W) * x_data + sess.run(b))
  plt.xlabel('dimension 0')
  plt.ylabel('dimension 1')
  plt.title('Iteration' + str(step+1)+'of'+str(num_iterations))
  plt.show()
# Out:
# n iteration 1
# w =: 0.29934412
# b =: 0.51163936
# loss=: 0.16473472
# n iteration 2
# w =: 0.23416288
# b =: 0.5115395
# loss=: 0.15873176
# n iteration 3
# w =: 0.20724806
# b =: 0.5114985
# loss=: 0.15770821
# n iteration 4
# w =: 0.19613431
# b =: 0.5114816
# loss=: 0.1575337
# n iteration 5
# w =: 0.1915452
# b =: 0.5114746
# loss=: 0.15750396
# n iteration 6
# w =: 0.18965025
# b =: 0.51147175
# loss=: 0.15749888
# n iteration 7
# w =: 0.18886778
# b =: 0.5114705
# loss=: 0.15749799
# n iteration 8
# w =: 0.18854468
# b =: 0.51147
# loss=: 0.15749787
# n iteration 9
# w =: 0.18841127
# b =: 0.51146984
# loss=: 0.15749784
# n iteration 10
# w =: 0.18835618
# b =: 0.5114697
# loss=: 0.15749784
